# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import tensorflow as tf
import numpy as np
import os
import matplotlib.pyplot as plt
from PIL import Image

# %%
IMG_CHANNELS, IMG_WIDTH, IMG_HEIGHT = 3, 512, 512

# %%
X_ids = next(os.walk('/content/gdrive/MyDrive/ml/images'))[2]
y_ids = next(os.walk('/content/gdrive/MyDrive/ml/masks'))[2]

# %%
LENGTH_DATA = len(X_ids)

X_train = np.zeros((LENGTH_DATA+1, 256, 256, 3), dtype=np.float32)
y_train = np.zeros((LENGTH_DATA+1, 256, 256, 1), dtype=np.bool)

for n, id_ in enumerate(X_ids):
    print(f'load image {id_}. Loaded {n}/{LENGTH_DATA} image')
    image = tf.keras.preprocessing.image.load_img(f'/content/gdrive/MyDrive/ml/images/{id_}', target_size=(IMG_HEIGHT, IMG_WIDTH))
    input_arr = tf.keras.preprocessing.image.img_to_array(image)[90:450,150:406]
    image = tf.keras.preprocessing.image.array_to_img(input_arr, ).resize((256, 256))
    X_train[n] = np.array(image)
    if n == LENGTH_DATA:
      break

for n, id_ in enumerate(X_ids):
    print(f'load image {id_}. Loaded {n}/{LENGTH_DATA} image')
    image = tf.keras.preprocessing.image.load_img(f'/content/gdrive/MyDrive/ml/masks/{id_}', 
                                                  target_size=(IMG_HEIGHT, IMG_WIDTH), color_mode="grayscale")
    input_arr = tf.keras.preprocessing.image.img_to_array(image)[90:450,150:406]
    image = tf.keras.preprocessing.image.array_to_img(input_arr).resize((256, 256))
    y_train[n] = np.array(image)[:, :, np.newaxis]
    if n == LENGTH_DATA:
      break
# Out:
# load image ds8_pexels-photo-847414_YitMRk4iyF.png. Loaded 853/2667 image
# load image ds8_pexels-photo-848547.png. Loaded 854/2667 image
# load image ds8_pexels-photo-850393_rTSqNMaEtx.png. Loaded 855/2667 image
# load image ds8_pexels-photo-848541.png. Loaded 856/2667 image
# load image ds8_pexels-photo-848544_EqKqLfiSDY.png. Loaded 857/2667 image
# load image ds8_pexels-photo-850391.png. Loaded 858/2667 image
# load image ds8_pexels-photo-848542.png. Loaded 859/2667 image
# load image ds8_pexels-photo-851658.png. Loaded 860/2667 image
# load image ds8_pexels-photo-848552.png. Loaded 861/2667 image
# load image ds8_pexels-photo-850394_e2aaqxP05q.png. Loaded 862/2667 image
# load image ds8_pexels-photo-848681.png. Loaded 863/2667 image
# load image ds8_pexels-photo-848554.png. Loaded 864/2667 image
# load image ds8_pexels-photo-850804.png. Loaded 865/2667 image
# load image ds8_pexels-photo-848306.png. Loaded 866/2667 image
# ...

# %%
fig = plt.figure()
ax1, ax2 = fig.subplots(1, 2)
ax1.imshow(tf.keras.preprocessing.image.array_to_img(X_train[1000]))
ax2.imshow(tf.keras.preprocessing.image.array_to_img(y_train[1000]))
plt.show()

# %%
inputs = tf.keras.layers.Input((256, 256, 3))
s = tf.keras.layers.Lambda(lambda x: x / 255)(inputs)

#Contraction path
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
c1 = tf.keras.layers.Dropout(0.1)(c1)
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
c2 = tf.keras.layers.Dropout(0.1)(c2)
c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)
 
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
c3 = tf.keras.layers.Dropout(0.2)(c3)
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)
 
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
c4 = tf.keras.layers.Dropout(0.2)(c4)
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
p4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c4)
 
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
c5 = tf.keras.layers.Dropout(0.3)(c5)
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

#Expansive path 
u6 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
u6 = tf.keras.layers.concatenate([u6, c4])
c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
c6 = tf.keras.layers.Dropout(0.2)(c6)
c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)
 
u7 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
u7 = tf.keras.layers.concatenate([u7, c3])
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
c7 = tf.keras.layers.Dropout(0.2)(c7)
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)
 
u8 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
u8 = tf.keras.layers.concatenate([u8, c2])
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
c8 = tf.keras.layers.Dropout(0.1)(c8)
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)
 
u9 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
c9 = tf.keras.layers.Dropout(0.1)(c9)
c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)
 
outputs = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)
 
model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 256, 256, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 16) 448         lambda[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256, 256, 16) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 16) 2320        dropout[0][0]
# ...

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
results = model.fit(X_train, y_train, validation_split=0.1, batch_size=16, epochs=50)
# Out:
# Epoch 1/50
# 151/151 [==============================] - 22s 147ms/step - loss: 0.1294 - accuracy: 0.9507 - val_loss: 0.3703 - val_accuracy: 0.8762
# Epoch 2/50
# 151/151 [==============================] - 22s 148ms/step - loss: 0.1108 - accuracy: 0.9575 - val_loss: 0.3707 - val_accuracy: 0.8771
# Epoch 3/50
# 151/151 [==============================] - 22s 146ms/step - loss: 0.0927 - accuracy: 0.9646 - val_loss: 0.3962 - val_accuracy: 0.8716
# Epoch 4/50
# 151/151 [==============================] - 22s 145ms/step - loss: 0.1002 - accuracy: 0.9619 - val_loss: 0.3836 - val_accuracy: 0.8801
# Epoch 5/50
# 151/151 [==============================] - 22s 146ms/step - loss: 0.0878 - accuracy: 0.9665 - val_loss: 0.4250 - val_accuracy: 0.8803
# Epoch 6/50
# 151/151 [==============================] - 22s 147ms/step - loss: 0.0930 - accuracy: 0.9646 - val_loss: 0.4090 - val_accuracy: 0.8808
# Epoch 7/50
# ...

# %%
# summarize history for accuracy
plt.plot(results.history['accuracy'])
plt.plot(results.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import random
import cv2
# model.save("/content/gdrive/MyDrive/ml/model.h5")
test_id = random.choice(X_ids)
img = tf.keras.preprocessing.image.load_img(f"/content/gdrive/MyDrive/ml/images/{test_id}", target_size=(256, 256))
input_array = tf.keras.preprocessing.image.img_to_array(img)
input_array = np.array([input_array])  # Convert single image to a batch.
predictions = model.predict(input_array)
mask = np.array(predictions[0])
mask = cv2.normalize(mask, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)

fig = plt.figure(figsize=(16,9))
ax1, ax2, ax3 = fig.subplots(1, 3)
ax1.imshow(img)
ax2.imshow(tf.keras.preprocessing.image.load_img(f"/content/gdrive/MyDrive/ml/masks/{test_id}", target_size=(256, 256)))
ax3.imshow(mask, cmap="gray")
plt.show()
